# %%
# https://github.com/dragen1860/TensorFlow-2.x-Tutorials/blob/master/09-RNN-Sentiment-Analysis/main.py
# https://shiva-verma.medium.com/understanding-input-and-output-shape-in-lstm-keras-c501ee95c65e

# %%
import  os
import  tensorflow as tf
import  numpy as np
from    tensorflow import keras
# Out:
# 2021-09-18 20:55:32.304933: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
tf.random.set_seed(22)
np.random.seed(22)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
assert tf.__version__.startswith('2.')

# %%
# fix random seed for reproducibility
np.random.seed(7)
# load the dataset but only keep the top n words, zero the rest
top_words = 10000
# truncate and pad input sequences
max_review_length = 80
(X_train, y_train), (X_test, y_test) = keras.datasets.imdb.load_data(num_words=top_words)
# https://www.tensorflow.org/api_docs/python/tf/keras/datasets/imdb/load_data
# https://ai.stanford.edu/~amaas/data/sentiment/

print(X_train.shape, X_train[0], y_train.shape)
# X_train = tf.convert_to_tensor(X_train)
# y_train = tf.one_hot(y_train, depth=2)
print('Pad sequences (samples x time)')
x_train = keras.preprocessing.sequence.pad_sequences(X_train, maxlen=max_review_length)
x_test = keras.preprocessing.sequence.pad_sequences(X_test, maxlen=max_review_length)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/datasets/imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/datasets/imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])
# (25000,) [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32] (25000,)
# Pad sequences (samples x time)
# x_train shape: (25000, 80)
# x_test shape: (25000, 80)

# %%
print(x_train[0,:], np.max(y_train), y_train.shape)
# Out:
# [  15  256    4    2    7 3766    5  723   36   71   43  530  476   26
#   400  317   46    7    4    2 1029   13  104   88    4  381   15  297
#    98   32 2071   56   26  141    6  194 7486   18    4  226   22   21
#   134  476   26  480    5  144   30 5535   18   51   36   28  224   92
#    25  104    4  226   65   16   38 1334   88   12   16  283    5   16
#  4472  113  103   32   15   16 5345   19  178   32] 1 (25000,)

# %%
class RNN(keras.Model):

    def __init__(self, units, num_classes, num_layers):
        super(RNN, self).__init__()


        # self.cells = [keras.layers.LSTMCell(units) for _ in range(num_layers)]
        #
        # self.rnn = keras.layers.RNN(self.cells, unroll=True)
        self.rnn = keras.layers.LSTM(units, return_sequences=True)
        self.rnn2 = keras.layers.LSTM(units)

        # https://shiva-verma.medium.com/understanding-input-and-output-shape-in-lstm-keras-c501ee95c65e

        # self.cells = (keras.layers.LSTMCell(units) for _ in range(num_layers))
        # #
        # self.rnn = keras.layers.RNN(self.cells, return_sequences=True, return_state=True)
        # self.rnn = keras.layers.LSTM(units, unroll=True)
        # self.rnn = keras.layers.StackedRNNCells(self.cells)


        # have 1000 words totally, every word will be embedding into 100 length vector
        # the max sentence lenght is 80 words
        self.embedding = keras.layers.Embedding(top_words, 100, input_length=max_review_length)
        self.fc = keras.layers.Dense(1)

    def call(self, inputs, training=None, mask=None):

        # print('x', inputs.shape)
        # [b, sentence len] => [b, sentence len, word embedding]
        x = self.embedding(inputs)
        # print('embedding', x.shape)
        x = self.rnn(x) 
        x = self.rnn2(x) 
        # print('rnn', x.shape)

        x = self.fc(x)
        print(x.shape)

        return x

# %%
def main():

    units = 64
    num_classes = 2
    batch_size = 32
    epochs = 20

    model = RNN(units, num_classes, num_layers=2)


    model.compile(optimizer=keras.optimizers.Adam(0.001),
                  loss=keras.losses.BinaryCrossentropy(from_logits=True),
                  metrics=['accuracy'])

    # train
    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
              validation_data=(x_test, y_test), verbose=1)

    # evaluate on test set
    scores = model.evaluate(x_test, y_test, batch_size, verbose=1)
    print("Final test loss and accuracy :", scores)




if __name__ == '__main__':
    main()
# Out:
# 2021-09-18 20:56:06.785211: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-18 20:56:06.788806: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-09-18 20:56:06.830302: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 20:56:06.830899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-18 20:56:06.830968: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-18 20:56:06.861763: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-18 20:56:06.861852: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-18 20:56:06.878223: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-18 20:56:06.901015: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-18 20:56:06.929926: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-18 20:56:06.936903: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-18 20:56:06.939357: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-18 20:56:06.939531: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 20:56:06.940240: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 20:56:06.941782: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-18 20:56:06.942295: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-18 20:56:06.942498: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-18 20:56:06.942663: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 20:56:06.943334: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-18 20:56:06.943380: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-18 20:56:06.943404: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-18 20:56:06.943420: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-18 20:56:06.943436: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-18 20:56:06.943452: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-18 20:56:06.943467: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-18 20:56:06.943487: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-18 20:56:06.943504: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-18 20:56:06.943584: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 20:56:06.944203: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 20:56:06.944723: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-18 20:56:06.945884: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-18 20:56:08.355359: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-09-18 20:56:08.355407: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-09-18 20:56:08.355417: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-09-18 20:56:08.357293: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 20:56:08.358001: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 20:56:08.358617: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 20:56:08.359185: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14957 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2021-09-18 20:56:08.982899: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-18 20:56:08.997450: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2000185000 Hz
# Epoch 1/20
# (None, 1)
# (None, 1)
# 2021-09-18 20:56:11.449916: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-18 20:56:12.167829: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-18 20:56:12.223202: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 781/782 [============================>.] - ETA: 0s - loss: 0.5023 - accuracy: 0.7201(None, 1)
# 782/782 [==============================] - 25s 21ms/step - loss: 0.5021 - accuracy: 0.7203 - val_loss: 0.3665 - val_accuracy: 0.8286
# Epoch 2/20
# 782/782 [==============================] - 15s 19ms/step - loss: 0.2547 - accuracy: 0.8922 - val_loss: 0.3763 - val_accuracy: 0.8424
# Epoch 3/20
# 782/782 [==============================] - 15s 20ms/step - loss: 0.1738 - accuracy: 0.9338 - val_loss: 0.4449 - val_accuracy: 0.8334
# Epoch 4/20
# 782/782 [==============================] - 15s 19ms/step - loss: 0.1172 - accuracy: 0.9551 - val_loss: 0.4835 - val_accuracy: 0.8279
# Epoch 5/20
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0768 - accuracy: 0.9717 - val_loss: 0.5369 - val_accuracy: 0.8277
# Epoch 6/20
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0489 - accuracy: 0.9846 - val_loss: 0.7399 - val_accuracy: 0.8137
# Epoch 7/20
# 782/782 [==============================] - 15s 20ms/step - loss: 0.0364 - accuracy: 0.9882 - val_loss: 0.9020 - val_accuracy: 0.8216
# Epoch 8/20
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0266 - accuracy: 0.9919 - val_loss: 0.8589 - val_accuracy: 0.8183
# Epoch 9/20
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0263 - accuracy: 0.9918 - val_loss: 0.8608 - val_accuracy: 0.8207
# Epoch 10/20
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0188 - accuracy: 0.9940 - val_loss: 0.8584 - val_accuracy: 0.8232
# Epoch 11/20
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0184 - accuracy: 0.9942 - val_loss: 0.9399 - val_accuracy: 0.8214
# Epoch 12/20
# 782/782 [==============================] - 15s 20ms/step - loss: 0.0120 - accuracy: 0.9964 - val_loss: 1.0144 - val_accuracy: 0.8214
# Epoch 13/20
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0095 - accuracy: 0.9974 - val_loss: 1.0493 - val_accuracy: 0.8226
# Epoch 14/20
# 782/782 [==============================] - 15s 20ms/step - loss: 0.0130 - accuracy: 0.9954 - val_loss: 0.9986 - val_accuracy: 0.8014
# Epoch 15/20
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0161 - accuracy: 0.9948 - val_loss: 1.1913 - val_accuracy: 0.8199
# Epoch 16/20
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 1.1808 - val_accuracy: 0.8051
# Epoch 17/20
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.9754 - val_accuracy: 0.8171
# Epoch 18/20
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0080 - accuracy: 0.9975 - val_loss: 1.1341 - val_accuracy: 0.8157
# Epoch 19/20
# 782/782 [==============================] - 15s 19ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 1.1003 - val_accuracy: 0.8185
# Epoch 20/20
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 1.1258 - val_accuracy: 0.8185
# 782/782 [==============================] - 3s 4ms/step - loss: 1.1258 - accuracy: 0.8185
# Final test loss and accuracy : [1.1258373260498047, 0.8185200095176697]
