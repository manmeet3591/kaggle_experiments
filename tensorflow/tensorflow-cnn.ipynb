# %%
# https://github.com/dragen1860/TensorFlow-2.x-Tutorials/blob/master/05-FashionMNIST/mnist_fit.py

# %%
import  os
import  tensorflow as tf
from    tensorflow import keras
from    tensorflow.keras import layers, optimizers, datasets
# Out:
# 2021-09-17 05:44:20.718490: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
def prepare_mnist_features_and_labels(x, y):
    x = tf.cast(x, tf.float32) / 255.0
    y = tf.cast(y, tf.int64)

    return x, y

# %%
def mnist_dataset():
    (x, y), (x_val, y_val) = datasets.fashion_mnist.load_data()
    print('x/y shape:', x.shape, y.shape)
    y = tf.one_hot(y, depth=10)
    # https://www.tensorflow.org/api_docs/python/tf/one_hot
    y_val = tf.one_hot(y_val, depth=10)
    ds = tf.data.Dataset.from_tensor_slices((x, y))
    ds = ds.map(prepare_mnist_features_and_labels)
    ds = ds.shuffle(60000).batch(100)

    ds_val = tf.data.Dataset.from_tensor_slices((x_val, y_val))
    ds_val = ds_val.map(prepare_mnist_features_and_labels)
    ds_val = ds_val.shuffle(10000).batch(100)

    return ds,ds_val

# %%
def main():
    os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # or any {'0', '1', '2'}

    train_dataset, val_dataset = mnist_dataset()

    model = keras.Sequential([
        layers.Reshape(target_shape=(28 * 28,), input_shape=(28, 28)),
        layers.Dense(200, activation='relu'),
        layers.Dense(200, activation='relu'),
        layers.Dense(200, activation='relu'),
        layers.Dense(10)])
    # no need to use compile if you have no loss/optimizer/metrics involved here.
    model.compile(optimizer=optimizers.Adam(0.001),
                  loss=tf.losses.CategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])

    model.fit(train_dataset.repeat(), epochs=30, steps_per_epoch=500,
              validation_data=val_dataset.repeat(),
              validation_steps=2
              )


if __name__ == '__main__':
    main()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# x/y shape: (60000, 28, 28) (60000,)
# 2021-09-17 05:44:32.576660: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-17 05:44:32.579874: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-09-17 05:44:32.630321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 05:44:32.630915: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-17 05:44:32.630969: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-17 05:44:32.663319: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-17 05:44:32.663410: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-17 05:44:32.679533: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-17 05:44:32.719225: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-17 05:44:32.762420: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-17 05:44:32.769868: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-17 05:44:32.772593: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-17 05:44:32.772741: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 05:44:32.773389: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 05:44:32.775267: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-17 05:44:32.777193: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-17 05:44:32.778056: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-17 05:44:32.778222: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 05:44:32.778782: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-17 05:44:32.778817: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-17 05:44:32.778838: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-17 05:44:32.778853: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-17 05:44:32.778868: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-17 05:44:32.778882: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-17 05:44:32.778896: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-17 05:44:32.778912: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-17 05:44:32.778927: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-17 05:44:32.779025: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 05:44:32.779671: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 05:44:32.780216: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-17 05:44:32.781094: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-17 05:44:34.230617: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-09-17 05:44:34.230671: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-09-17 05:44:34.230683: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-09-17 05:44:34.232567: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 05:44:34.233425: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 05:44:34.234087: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 05:44:34.234680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14957 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Epoch 1/30
# 2021-09-17 05:44:35.064955: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-17 05:44:35.071508: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2000185000 Hz
# 2021-09-17 05:44:35.159449: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-17 05:44:36.204273: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 500/500 [==============================] - 4s 4ms/step - loss: 0.7106 - accuracy: 0.7526 - val_loss: 0.2981 - val_accuracy: 0.9050
# Epoch 2/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.3985 - accuracy: 0.8542 - val_loss: 0.3671 - val_accuracy: 0.8750
# Epoch 3/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.3475 - accuracy: 0.8719 - val_loss: 0.3186 - val_accuracy: 0.8900
# Epoch 4/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.3257 - accuracy: 0.8807 - val_loss: 0.3634 - val_accuracy: 0.8850
# Epoch 5/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2931 - accuracy: 0.8901 - val_loss: 0.3571 - val_accuracy: 0.8650
# Epoch 6/30
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2845 - accuracy: 0.8931 - val_loss: 0.2776 - val_accuracy: 0.8800
# Epoch 7/30
# 500/500 [==============================] - 3s 3ms/step - loss: 0.2693 - accuracy: 0.8996 - val_loss: 0.3864 - val_accuracy: 0.8800
# Epoch 8/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2593 - accuracy: 0.9032 - val_loss: 0.3803 - val_accuracy: 0.8550
# Epoch 9/30
# 500/500 [==============================] - 3s 5ms/step - loss: 0.2539 - accuracy: 0.9044 - val_loss: 0.2423 - val_accuracy: 0.9200
# Epoch 10/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2488 - accuracy: 0.9051 - val_loss: 0.3291 - val_accuracy: 0.8850
# Epoch 11/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2369 - accuracy: 0.9095 - val_loss: 0.2505 - val_accuracy: 0.9100
# Epoch 12/30
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2212 - accuracy: 0.9163 - val_loss: 0.2533 - val_accuracy: 0.9000
# Epoch 13/30
# 500/500 [==============================] - 3s 3ms/step - loss: 0.2178 - accuracy: 0.9165 - val_loss: 0.3052 - val_accuracy: 0.9050
# Epoch 14/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2170 - accuracy: 0.9163 - val_loss: 0.2688 - val_accuracy: 0.9200
# Epoch 15/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2030 - accuracy: 0.9227 - val_loss: 0.2726 - val_accuracy: 0.9050
# Epoch 16/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2043 - accuracy: 0.9216 - val_loss: 0.2695 - val_accuracy: 0.8950
# Epoch 17/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2002 - accuracy: 0.9238 - val_loss: 0.3067 - val_accuracy: 0.8850
# Epoch 18/30
# 500/500 [==============================] - 2s 3ms/step - loss: 0.1858 - accuracy: 0.9286 - val_loss: 0.2946 - val_accuracy: 0.9200
# Epoch 19/30
# 500/500 [==============================] - 3s 3ms/step - loss: 0.1812 - accuracy: 0.9295 - val_loss: 0.4072 - val_accuracy: 0.8950
# Epoch 20/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.1760 - accuracy: 0.9313 - val_loss: 0.3865 - val_accuracy: 0.8750
# Epoch 21/30
# 500/500 [==============================] - 3s 5ms/step - loss: 0.1823 - accuracy: 0.9294 - val_loss: 0.5275 - val_accuracy: 0.8850
# Epoch 22/30
# 500/500 [==============================] - 3s 5ms/step - loss: 0.1682 - accuracy: 0.9359 - val_loss: 0.2823 - val_accuracy: 0.9100
# Epoch 23/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.1623 - accuracy: 0.9367 - val_loss: 0.2411 - val_accuracy: 0.9050
# Epoch 24/30
# 500/500 [==============================] - 1s 3ms/step - loss: 0.1484 - accuracy: 0.9422 - val_loss: 0.3369 - val_accuracy: 0.8900
# Epoch 25/30
# 500/500 [==============================] - 3s 3ms/step - loss: 0.1493 - accuracy: 0.9425 - val_loss: 0.5753 - val_accuracy: 0.8950
# Epoch 26/30
# 500/500 [==============================] - 3s 5ms/step - loss: 0.1537 - accuracy: 0.9397 - val_loss: 0.4049 - val_accuracy: 0.8800
# Epoch 27/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.1519 - accuracy: 0.9411 - val_loss: 0.3001 - val_accuracy: 0.9050
# Epoch 28/30
# 500/500 [==============================] - 3s 6ms/step - loss: 0.1489 - accuracy: 0.9427 - val_loss: 0.4190 - val_accuracy: 0.8950
# Epoch 29/30
# 500/500 [==============================] - 3s 5ms/step - loss: 0.1414 - accuracy: 0.9454 - val_loss: 0.6584 - val_accuracy: 0.8850
# Epoch 30/30
# 500/500 [==============================] - 1s 3ms/step - loss: 0.1293 - accuracy: 0.9510 - val_loss: 0.4069 - val_accuracy: 0.9100
